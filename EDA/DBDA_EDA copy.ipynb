# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objects as go

# %%
df = pd.read_csv("DBDA_Cleaned_for_UI.csv")

# %%
pd.set_option('display.max_columns', None)  # Show all columns

pd.set_option('display.float_format', '{:.0f}'.format)  # Disable scientific notation

df.head()
# Out:
#    form_number          PRN CCATrank         DOB  10th_percentage  \
# 0    210304041 210545000000     3971  1996-09-14               72
# 1    210300482 210545000000     3941  1997-06-18               63
# 2    210301188 210545000000     3421  1998-01-23               70
# 3    210301880 210545000000     2937  1996-09-28               85
# 4    210301787 210545000000     3843  1994-07-06               80
#
#    grad_percentage  pg_percentage pre_ccat DBMSTheory DBMSLab  DBMSTotal  \
# 0               71            NaN       no         27      24         51
# 1               64            NaN       no         33      27         60
# 2               63            NaN       no         20      24         44
# 3               61            NaN       no         35      24         59
# 4               58            NaN       no         19      33         52
#
#   DBMSStatus JavaTheory  JavaLab  JavaTotal JavaStatus PythonRTheory  \
# ...

# %%
df = df.drop(columns=['form_number', 'PRN', 'CCATrank', 'DOB'])

# %%
df.describe()
# Out:
#        10th_percentage  grad_percentage  pg_percentage  DBMSTotal  JavaLab  \
# count              295              291             25        294      294
# mean                81               97             74         65       39
# std                  9              467             15         12        9
# min                 50               43              7          0        3
# 25%                 76               63             73         58       32
# 50%                 82               69             76         65       40
# 75%                 89               75             81         74       46
# max                 97             8037             87         91       59
#
#        JavaTotal  PythonRLab  PythonRTotal  StatsLab  StatsTotal  \
# count        294         294           294       238         238
# mean          63          42            66        41          63
# std           13           9            12         8          11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 47 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   10th_percentage     295 non-null    float64
#  1   grad_percentage     291 non-null    float64
#  2   pg_percentage       25 non-null     float64
#  3   pre_ccat            295 non-null    object
#  4   DBMSTheory          294 non-null    object
#  5   DBMSLab             294 non-null    object
#  6   DBMSTotal           294 non-null    float64
#  7   DBMSStatus          294 non-null    object
#  8   JavaTheory          294 non-null    object
#  9   JavaLab             294 non-null    float64
#  10  JavaTotal           294 non-null    float64
#  11  JavaStatus          294 non-null    object
#  12  PythonRTheory       294 non-null    object
#  13  PythonRLab          294 non-null    float64
#  14  PythonRTotal        294 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# 10th_percentage         0
# grad_percentage         4
# pg_percentage         270
# pre_ccat                0
# DBMSTheory              1
# DBMSLab                 1
# DBMSTotal               1
# DBMSStatus              1
# JavaTheory              1
# JavaLab                 1
# JavaTotal               1
# JavaStatus              1
# PythonRTheory           1
# PythonRLab              1
# PythonRTotal            1
# PythonRStatus           1
# StatsTheory            57
# StatsLab               57
# StatsTotal             57
# StatsStatus            57
# DataVizTheory           1
# DataVizLab              1
# DataVizTotal            1
# DataVizStatus           1
# BigDataTheory           1
# BigDataLab              1
# BigDataTotal            1
# BigDataStatus           1
# LinuxCloudTheory       57
# LinuxCloudLab          57
# LinuxCloudTotal        57
# LinuxCloudStatus       57
# MLTheory                1
# MLLab                   1
# MLTotal                 1
# ...

# %%
df.nunique()
# Out:
# 10th_percentage       192
# grad_percentage       247
# pg_percentage          25
# pre_ccat                2
# DBMSTheory             24
# DBMSLab                42
# DBMSTotal              52
# DBMSStatus              2
# JavaTheory             24
# JavaLab                38
# JavaTotal              52
# JavaStatus              2
# PythonRTheory          23
# PythonRLab             39
# PythonRTotal           51
# PythonRStatus           2
# StatsTheory            21
# StatsLab               36
# StatsTotal             47
# StatsStatus             2
# DataVizTheory          23
# DataVizLab             39
# DataVizTotal           46
# DataVizStatus           2
# BigDataTheory          26
# BigDataLab             44
# BigDataTotal           51
# BigDataStatus           2
# LinuxCloudTheory       22
# LinuxCloudLab          37
# LinuxCloudTotal        51
# LinuxCloudStatus        2
# MLTheory               24
# MLLab                  42
# MLTotal                58
# ...

# %%
# Set plot style
sns.set_style("whitegrid")

# Create subplots for histograms of marks and percentages
fig, axes = plt.subplots(3, 2, figsize=(12, 10))

# Histogram for 10th_percentage
sns.histplot(df['10th_percentage'], bins=20, kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Distribution of 10th Percentage')

# Histogram for grad_percentage
sns.histplot(df['grad_percentage'].dropna(), bins=20, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Distribution of Graduation Percentage')
 
# Histogram for pg_percentage
sns.histplot(df['pg_percentage'].dropna(), bins=20, kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Distribution of Post-Graduation Percentage')

# Histogram for overall Percentage
sns.histplot(df['Percentage'].dropna(), bins=20, kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Distribution of Final Percentage')

# Histogram for Higher Education Percentage
sns.histplot(df['Higher_Edu_Percent'].dropna(), bins=20, kde=True, ax=axes[2, 0])
axes[2, 0].set_title('Distribution of Higher_Edu_Percent')

plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['10th_percentage', 'grad_percentage', 'pg_percentage', 'pre_ccat',
#        'DBMSTheory', 'DBMSLab', 'DBMSTotal', 'DBMSStatus', 'JavaTheory',
#        'JavaLab', 'JavaTotal', 'JavaStatus', 'PythonRTheory', 'PythonRLab',
#        'PythonRTotal', 'PythonRStatus', 'StatsTheory', 'StatsLab',
#        'StatsTotal', 'StatsStatus', 'DataVizTheory', 'DataVizLab',
#        'DataVizTotal', 'DataVizStatus', 'BigDataTheory', 'BigDataLab',
#        'BigDataTotal', 'BigDataStatus', 'LinuxCloudTheory', 'LinuxCloudLab',
#        'LinuxCloudTotal', 'LinuxCloudStatus', 'MLTheory', 'MLLab', 'MLTotal',
#        'MLStatus', 'Total', 'Percentage', 'Grade', 'Result', 'AptiGrade',
#        'ProjectGrade', 'Company_Name', 'Package', 'Higher_Edu_Percent',
#        'Is_Placed', 'branch_cleaned'],
#       dtype='object')

# %% [markdown]
# Subject Theory

# %%
course_columns =['DBMSTheory', 'JavaTheory', 'PythonRTheory', 'StatsTheory',
 'DataVizTheory', 'BigDataTheory', 'LinuxCloudTheory', 'MLTheory']

fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(12, 10))  # Create a grid layout
axes = axes.flatten()  # Flatten to easily iterate over

for i, column in enumerate(course_columns):
    sns.histplot(df[column], kde=True, bins=20, ax=axes[i], alpha=0.5)
    axes[i].set_title(f"Distribution of {column}")

# Remove any empty subplot
if len(course_columns) < len(axes):
    for j in range(len(course_columns), len(axes)):
        fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Subject Lab

# %%
course_columns = ['DBMSLab', 'JavaLab', 'PythonRLab', 'StatsLab',
 'DataVizLab', 'BigDataLab', 'LinuxCloudLab', 'MLLab']

fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(12, 10))  # Create a grid layout
axes = axes.flatten()  # Flatten to easily iterate over

for i, column in enumerate(course_columns):
    sns.histplot(df[column], kde=True, bins=20, ax=axes[i], alpha=0.5)
    axes[i].set_title(f"Distribution of {column}")

# Remove any empty subplot
if len(course_columns) < len(axes):
    for j in range(len(course_columns), len(axes)):
        fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
df[['DBMSTheory', 'JavaTheory', 'PythonRTheory', 'StatsTheory','DataVizTheory', 'BigDataTheory', 'LinuxCloudTheory', 'MLTheory', 'Is_Placed']]
# Out:
#     DBMSTheory JavaTheory PythonRTheory StatsTheory DataVizTheory  \
# 0           27         26            30         NaN            23
# 1           33         23            34         NaN            25
# 2           20         10            11         NaN            16
# 3           35         16            28         NaN            31
# 4           19         16            16         NaN            16
# ..         ...        ...           ...         ...           ...
# 290         32         20            30          20            32
# 291         32         27            32          20            34
# 292         31         29            31          25            29
# 293         32         26            25          18            33
# 294         31         22            22          18            29
#
#     BigDataTheory LinuxCloudTheory MLTheory Is_Placed
# 0              21              NaN       31       Yes
# 1              25              NaN       33       Yes
# ...

# %%
course_columns = ['DBMSTotal', 'JavaTotal', 'PythonRTotal', 'StatsTotal','DataVizTotal', 'BigDataTotal', 'LinuxCloudTotal', 'MLTotal']
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(12, 10))  # Create a grid layout
axes = axes.flatten()  # Flatten to easily iterate over

for i, column in enumerate(course_columns):
    sns.histplot(df[column], kde=True, bins=20, ax=axes[i], alpha=0.5)
    axes[i].set_title(f"Distribution of {column}")

# Remove any empty subplot
if len(course_columns) < len(axes):
    for j in range(len(course_columns), len(axes)):
        fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# Ensure there are no NaN values
df = df.dropna(subset=['Is_Placed'])

# %%
subjects = ['DBMSTheory', 'JavaTheory', 'PythonRTheory', 'StatsTheory',
            'DataVizTheory', 'BigDataTheory', 'LinuxCloudTheory', 'MLTheory']

# Drop rows where any subject has NaN values
df = df.dropna(subset=subjects)

# Convert all subject columns to numeric, coercing errors
df[subjects] = df[subjects].apply(pd.to_numeric, errors='coerce')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# List of subjects
subjects = ['DBMSTheory', 'JavaTheory', 'PythonRTheory', 'StatsTheory',
            'DataVizTheory', 'BigDataTheory', 'LinuxCloudTheory', 'MLTheory']

# Number of rows and columns for the grid
n_rows = 3
n_cols = 3

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 12))
axes = axes.flatten()  # Flatten the 2D array for easy indexing

# Plot boxplots for each subject
for i, subject in enumerate(subjects):
    sns.boxplot(x='Is_Placed', y=subject, data=df, ax=axes[i])
    axes[i].set_title(f'Effect of {subject} on Placement')
    axes[i].set_xlabel('Placement Status')
    axes[i].set_ylabel(f'{subject} Marks')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
subjects = ['DBMSLab', 'JavaLab', 'PythonRLab', 'StatsLab',
 'DataVizLab', 'BigDataLab', 'LinuxCloudLab', 'MLLab']

# Drop rows where any subject has NaN values
df = df.dropna(subset=subjects)

# Convert all subject columns to numeric, coercing errors
df[subjects] = df[subjects].apply(pd.to_numeric, errors='coerce')

# %%
subjects = ['DBMSLab', 'JavaLab', 'PythonRLab', 'StatsLab',
 'DataVizLab', 'BigDataLab', 'LinuxCloudLab', 'MLLab']

# Number of rows and columns for the grid
n_rows = 3
n_cols = 3

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 12))
axes = axes.flatten()  # Flatten the 2D array for easy indexing

# Plot boxplots for each subject
for i, subject in enumerate(subjects):
    sns.boxplot(x='Is_Placed', y=subject, data=df, ax=axes[i])
    axes[i].set_title(f'Effect of {subject} on Placement')
    axes[i].set_xlabel('Placement Status')
    axes[i].set_ylabel(f'{subject} Marks')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
subjects = ['DBMSTotal', 'JavaTotal', 'PythonRTotal', 'StatsTotal','DataVizTotal', 'BigDataTotal', 'LinuxCloudTotal', 'MLTotal']

# Drop rows where any subject has NaN values
df = df.dropna(subset=subjects)

# Convert all subject columns to numeric, coercing errors
df[subjects] = df[subjects].apply(pd.to_numeric, errors='coerce')

# %%
subjects = ['DBMSTotal', 'JavaTotal', 'PythonRTotal', 'StatsTotal','DataVizTotal', 'BigDataTotal', 'LinuxCloudTotal', 'MLTotal']
# Number of rows and columns for the grid
n_rows = 3
n_cols = 3

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 12))
axes = axes.flatten()  # Flatten the 2D array for easy indexing

# Plot boxplots for each subject
for i, subject in enumerate(subjects):
    sns.boxplot(x='Is_Placed', y=subject, data=df, ax=axes[i])
    axes[i].set_title(f'Effect of {subject} on Placement')
    axes[i].set_xlabel('Placement Status')
    axes[i].set_ylabel(f'{subject} Marks')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.countplot(x='Grade', hue='Is_Placed', data=df, palette='Set2')

plt.xlabel('Grade')
plt.ylabel('Count')
plt.title('Effect of Grade on Placement')
plt.legend(title='Placement Status', labels=['Not Placed (0)', 'Placed (1)'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(x='Is_Placed', y='Percentage', data=df, palette='coolwarm')

plt.xlabel('Placement Status (0 = Not Placed, 1 = Placed)')
plt.ylabel('Percentage')
plt.title('Effect of Percentage on Placement')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9456\2438376989.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Is_Placed', y='Percentage', data=df, palette='coolwarm')

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='ProjectGrade', hue='Is_Placed', data=df, palette='Set2')

plt.xlabel('ProjectGrade')
plt.ylabel('Count')
plt.title('Effect of ProjectGrade on Placement')
plt.legend(title='Placement Status', labels=['Not Placed (0)', 'Placed (1)'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert 'yes'/'no' to 1/0 for easier plotting
df['pre_ccat'] = df['pre_ccat'].map({'yes': 1, 'no': 0})

plt.figure(figsize=(6, 4))
sns.countplot(x='pre_ccat', hue='Is_Placed', data=df, palette='coolwarm')

# Labels and title
plt.xlabel('Pre-CCAT Status (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.title('Effect of Pre-CCAT on Placement')
plt.legend(title='Placement Status', labels=['Not Placed', 'Placed'])

# Show plot
plt.show()

# %%
df
# Out:
#      10th_percentage  grad_percentage  pg_percentage  pre_ccat  DBMSTheory  \
# 56                95               84            NaN         1          36
# 57                88               58            NaN         1          26
# 58                89               69            NaN         1          34
# 59                94               61            NaN         0          28
# 60                81               59            NaN         1          34
# ..               ...              ...            ...       ...         ...
# 290               82               71            NaN         0          32
# 291               77               72            NaN         1          32
# 292               90               87            NaN         0          31
# 293               84               84            NaN         1          32
# 294               86               60             74         0          31
#
# ...
